# %%
with open('/content/chatbot.txt') as file:
  key=file.read()

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

# %%
genai
# Out:
# <module 'google.generativeai' (<google.colab._import_hooks._hook_injector.HookInjectorLoader object at 0x7d239568ee10>)>

# %%
genai.configure(api_key=key)

# %%
genai.list_models()
# Out:
# <generator object list_models at 0x7d23855245e0>

# %%
tuple(genai.list_models())
# Out:
# (Model(name='models/embedding-gecko-001',
#        base_model_id='',
#        version='001',
#        display_name='Embedding Gecko',
#        description='Obtain a distributed representation of a text.',
#        input_token_limit=1024,
#        output_token_limit=1,
#        supported_generation_methods=['embedText', 'countTextTokens'],
#        temperature=None,
#        max_temperature=None,
#        top_p=None,
#        top_k=None),
#  Model(name='models/gemini-2.5-flash',
#        base_model_id='',
#        version='001',
#        display_name='Gemini 2.5 Flash',
#        description=('Stable version of Gemini 2.5 Flash, our mid-size multimodal model that '
#                     'supports up to 1 million tokens, released in June of 2025.'),
#        input_token_limit=1048576,
#        output_token_limit=65536,
#        supported_generation_methods=['generateContent',
#                                      'countTokens',
# ...

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# ...

# %%
model = genai.GenerativeModel(model_name = 'models/gemini-2.5-flash')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response = model.generate_content('Explain what is Generative AI?')
response.text
# Out:
# '**Generative AI** is a type of artificial intelligence that can **create new, original content** that has never existed before, rather than just analyzing or processing existing data.\n\nThink of it like an artificial "artist" or "writer" that has studied countless examples of a particular type of content (text, images, audio, code, etc.) and can then generate new pieces in a similar style or on a given topic, often in response to a simple prompt.\n\nHere\'s a breakdown of what that means:\n\n1.  **"Generative" Aspect:**\n    *   The core idea is to **generate** something new. Unlike traditional AI that might classify, predict, or recognize patterns in existing data (e.g., "Is this a cat or a dog?"), Generative AI *produces* outputs.\n    *   These outputs are not just copies; they are novel creations that often exhibit a level of creativity or coherence that mimics human-made content.\n\n2.  **How it Works (Simplified):**\n    *   **Training Data:** Generative AI models are trained
# ...

# %%
# !pip install IPython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00
# ...

# %%
from IPython.display import Image, Markdown

# %%
response = model.generate_content('Explain what is Generative AI?')
Markdown(response.text)
# Out:
# **Generative AI** is a type of artificial intelligence that can **create new content and ideas**, including conversations, stories, images, videos, and music.
#
# Unlike traditional AI that might classify, analyze, or predict based on existing data (e.g., identifying a cat in a picture, predicting stock prices, or recommending a product), Generative AI focuses on **producing novel outputs** that resemble the data it was trained on but are not identical copies.
#
# Here's a breakdown of what that means:
#
# 1.  **Learns Patterns and Structures:** Generative AI models are trained on vast datasets of existing content (e.g., millions of images, billions of text documents, hours of music). During this training, they learn the underlying patterns, styles, relationships, and characteristics of that data.
#
# ...

# %%
system_prompt = 'You are an expert in Generative AI, whenevr user asks some queries respond in very concise and informative way'
system_prompt
# Out:
# 'You are an expert in Generative AI, whenevr user asks some queries respond in very concise and informative way'

# %%
model = genai.GenerativeModel(model_name = 'models/gemini-2.5-flash-lite', system_instruction = system_prompt)
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-flash-lite',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction='You are an expert in Generative AI, whenevr user asks some queries respond in very concise and informative way',
#     cached_content=None
# )

# %%
response = model.generate_content('What is Generative AI?')
Markdown(response.text)
# Out:
# Generative AI refers to artificial intelligence systems that can **create new, original content**, such as text, images, music, or code, rather than just analyzing or acting on existing data.

# %%
# Loop - Prompt input - Model - Response
while True:
  # input prompt
  # response
# Out:
#   File "/tmp/ipython-input-62128701.py", line 4
#     # response
#               ^
# SyntaxError: incomplete input

# %%
chat = model.start_chat(history = [])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.5-flash-lite',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction='You are an expert in Generative AI, whenevr user asks some queries respond in very concise and informative way',
#         cached_content=None
#     ),
#     history=[]
# )

# %%
response = chat.send_message('What is Gen AI?')
Markdown(response.text)
# Out:
# Gen AI, or Generative AI, is a type of artificial intelligence that can create new, original content, such as text, images, music, and code. It learns from existing data and uses that knowledge to produce novel outputs.

# %%
chat.history
# Out:
# [parts {
#    text: "What is Gen AI?"
#  }
#  role: "user",
#  parts {
#    text: "Gen AI, or Generative AI, is a type of artificial intelligence that can create new, original content, such as text, images, music, and code. It learns from existing data and uses that knowledge to produce novel outputs."
#  }
#  role: "model"]

# %%
response = chat.send_message('Why Gen AI?')
Markdown(response.text)
# Out:
# Gen AI offers significant advantages:
#
# *   **Creativity & Innovation:** Enables the generation of novel ideas and content, pushing boundaries in art, design, and problem-solving.
# *   **Efficiency & Automation:** Automates repetitive content creation tasks, freeing up human resources for more complex work.
# *   **Personalization:** Allows for highly customized experiences and content tailored to individual needs and preferences.
# *   **Accessibility:** Democratizes content creation, making advanced tools accessible to a wider audience.
# *   **Exploration & Discovery:** Facilitates rapid prototyping and exploration of possibilities across various fields.

# %%
chat.history
# Out:
# [parts {
#    text: "What is Gen AI?"
#  }
#  role: "user",
#  parts {
#    text: "Gen AI, or Generative AI, is a type of artificial intelligence that can create new, original content, such as text, images, music, and code. It learns from existing data and uses that knowledge to produce novel outputs."
#  }
#  role: "model",
#  parts {
#    text: "Why Gen AI?"
#  }
#  role: "user",
#  parts {
# ...

# %%
response = chat.send_message('how Gen AI works?')
Markdown(response.text)
# Out:
# Gen AI typically works through deep learning models, most commonly **neural networks**. Here's a simplified breakdown:
#
# 1.  **Training Data:** The AI is fed vast amounts of existing data (text, images, music, code, etc.).
# 2.  **Pattern Learning:** The neural network learns complex patterns, relationships, and structures within this data. It identifies underlying rules and styles.
# 3.  **Generative Process:** Based on what it has learned, the AI can then:
#     *   **Predict the next element:** For text, it predicts the next word based on the preceding ones. For images, it might predict the next pixel or feature.
#     *   **Combine learned elements:** It can remix and recombine learned components in new ways.
#     *   **Follow prompts/instructions:** Users provide input (text prompts, desired style) to guide the generation process.
# 4.  **Output Creation:** The AI generates new content that mimics the characteristics of its training data but is original.
#
# ...

# %%
chat.history
# Out:
# [parts {
#    text: "What is Gen AI?"
#  }
#  role: "user",
#  parts {
#    text: "Gen AI, or Generative AI, is a type of artificial intelligence that can create new, original content, such as text, images, music, and code. It learns from existing data and uses that knowledge to produce novel outputs."
#  }
#  role: "model",
#  parts {
#    text: "Why Gen AI?"
#  }
#  role: "user",
#  parts {
# ...
